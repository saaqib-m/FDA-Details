# %%
import requests
import pandas as pd 
import time

# %%
# use requests and json to obtain the details from the api
# can adjust limit to obtain number of results
response = requests.get('https://api.fda.gov/food/enforcement.json?limit=1000').json()

# %%
# the 'results' section obtains the necessary information and [0] gets the first entry
response['results']
# Out:
# [{'country': 'United States',
#   'city': 'Davie',
#   'address_1': '4131 SW 47th Ave Ste 1403',
#   'reason_for_recall': 'Recall initiated as a precautionary measure due to potential risk of product contamination with Burkholderia cepacia.',
#   'address_2': '',
#   'product_quantity': '1,990 bottles',
#   'code_info': 'UPC No. 632687615989; Lot No. 30661601, Exp. Date 05/2018.',
#   'center_classification_date': '20161025',
#   'distribution_pattern': 'FL, MI, MS, and OH.',
#   'state': 'FL',
#   'product_description': 'CytoDetox, Hydrolyzed Clinoptilolite Fragments, 1 oz./30 mL, OTC Non-Sterile.  Dietary supplement.',
#   'report_date': '20161102',
#   'classification': 'Class II',
#   'openfda': {},
#   'recalling_firm': 'Pharmatech LLC',
#   'recall_number': 'F-0276-2017',
#   'initial_firm_notification': 'Letter',
#   'product_type': 'Food',
#   'event_id': '75272',
#   'more_code_info': '',
#   'recall_initiation_date': '20160808',
#   'postal_code': '33314-4036',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'status': 'Ongoing'},
#  {'country': 'United States',
#   'city': 'Millbrae',
#   'address_1': '375 Adrian Rd',
#   'reason_for_recall': 'Mooncake products, manufactured and distributed by Magic Gourmet Trading, Inc. of Milbrae, CA did not have adequate product labeling, including ingredient statements and allergen declaration. Undeclared ingredients include wheat, peanut oil.',
#   'address_2': '',
#   'product_quantity': '2 cases (1 pc/bx, 48bx/cs)',
#   'code_info': 'FG-M1MOT-UW  Best by Nov 1, 2016.',
#   'center_classification_date': '20170106',
#   'distribution_pattern': 'CA, WA, OR.',
#   'state': 'CA',
#   'product_description': 'Koi Palace Mini Moon Cake: Single Box - Mini Oolong Tea Paste  Unit Size 1/2 lb. and 1/4 lb. in circular box (1 piece) and rectangular boxes (4, 6 or 8 pieces).',
#   'report_date': '20170118',
#   'classification': 'Class II',
#   'openfda': {},
#   'recalling_firm': 'Magic Gourmet Trading Inc',
#   'recall_number': 'F-0865-2017',
#   'initial_firm_notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#   'product_type': 'Food',
#   'event_id': '75069',
#   'termination_date': '20170111',
#   'more_code_info': '',
#   'recall_initiation_date': '20160831',
#   'postal_code': '94030-3104',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'status': 'Terminated'},
#  {'country': 'United States',
#   'city': 'Miami',
#   'address_1': '13439 NW 19 LANE',
#   'reason_for_recall': 'Virginia State (VDACS) found Listeria monocytogenes in Lacteos Santa Martha Quesito Casero Fresh Curd (Best by 9/27/14), FDA made an inspection, were the environmental samples collected came up positive also for Listeria monocytogenes, also the Oasis Brands Inc. sent finish products samples to a private lab, the Lacteos Santa Martha Cuajada en Hoja Queso Casero Hecho a Mano Fresh Curd (Best By dates of 10/18/14 and 11/25/14) came also positive for Listeria monocytogenes.  Oasis Brands Inc.  is voluntarily recalling ALL their Lacteos Santa Martha brand products manufactured that are within expiration date.',
#   'address_2': '',
#   'product_quantity': '144 pieces',
#   'code_info': 'UPC 635349 000390  Best By dates: 07/01/14 thru 12/31/14',
#   'center_classification_date': '20141202',
#   'distribution_pattern': 'FL, GA. NC, and TN',
#   'state': 'FL',
#   'product_description': 'Crema GuateLinda (Guatemalan Style Cream) in individually soft poly/plastic bags labeled in part: Lacteos Santa Martha Crema GuateLinda Guatemalan Style Cream Net WT 1 LB (16 oz)',
#   'report_date': '20141210',
#   'classification': 'Class I',
#   'openfda': {},
#   'recalling_firm': 'Oasis Brands, Inc',
#   'recall_number': 'F-0609-2015',
#   'initial_firm_notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#   'product_type': 'Food',
#   'event_id': '69516',
#   'termination_date': '20170328',
#   'recall_initiation_date': '20141010',
#   'postal_code': '33182',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'status': 'Terminated'},
#  {'country': 'United States',
#   'city': 'Pompano Beach',
#   'address_1': '2300 NW 19th St',
#   'reason_for_recall': 'FreshPoint South Florida is recalling sliced fresh yellow onions and salsa products processed using yellow onions sourced from Gills Onions, LLC which were recalled for Listeria monocytogenes.',
#   'address_2': '',
#   'product_quantity': '7 cases',
#   'code_info': 'Item #   302940.',
#   'center_classification_date': '20120808',
#   'distribution_pattern': 'Products were distributed in South Florida.',
#   'state': 'FL',
#   'product_description': 'Yellow Onion.  Product is labeled in part:  "***FC Salsa Mango"***Refrigerate at 34 F***"      Item #   302940 FC SALSA MANGO 2/5#.        Product is fresh made - Ready To Eat.',
#   'report_date': '20120815',
#   'classification': 'Class I',
#   'openfda': {},
#   'recalling_firm': 'FreshPoint South Florida',
#   'recall_number': 'F-1922-2012',
#   'initial_firm_notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#   'product_type': 'Food',
#   'event_id': '62750',
#   'termination_date': '20141008',
#   'more_code_info': '',
#   'recall_initiation_date': '20120727',
#   'postal_code': '33069-5227',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'status': 'Terminated'},
#  {'country': 'United States',
#   'city': 'Rancho Dominguez',
#   'address_1': '2610 Homestead Pl',
#   'reason_for_recall': 'Firm was notified by supplier that Organic Ground Flaxseed powder was under recall by manufacturer due to unapproved herbicide - Haloxyfop',
#   'address_2': '',
#   'product_quantity': 'xx',
#   'code_info': 'Lot codes: 72746',
#   'center_classification_date': '20200413',
#   'distribution_pattern': 'nationwide, Canada and Netherlands',
#   'state': 'CA',
#   'product_description': 'Pure Planet Organic Parasite Cleanse;  Net Wt. 174g Glass Jar;  Finished Product Item # 52700    Manufactured and Distributed by:  Pure Planet,  Rancho Dominguez, CA',
#   'report_date': '20200401',
#   'classification': 'Class III',
#   'openfda': {},
#   'recalling_firm': 'Organic By Nature, Inc.',
#   'recall_number': 'F-0904-2020',
#   'initial_firm_notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#   'product_type': 'Food',
#   'event_id': '85253',
#   'termination_date': '20210202',
#   'more_code_info': '',
#   'recall_initiation_date': '20200224',
#   'postal_code': '90220-5610',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'status': 'Terminated'},
#  {'country': 'United States',
#   'city': 'Seattle',
#   'address_1': '3429 Airport Way S',
#   'reason_for_recall': 'Coffee Toffee is recalled because pecan is listed on the Ingredients statement but it is not listed in the Contains statement.',
#   'address_2': '',
#   'product_quantity': '24 packages',
#   'code_info': 'no codes',
#   'center_classification_date': '20180614',
#   'distribution_pattern': 'distributed in WA',
#   'state': 'WA',
#   'product_description': 'Coffee Toffee - 4 oz. packages. UPC 6 55974 89001 2.    The label is read in parts: "***Ingredients: butter (milk), sugar, bittersweet chocolate 60% (cocoa liquor, emulsifier, soya lecithin, vanilla), coffee, pecans *** Contains: milk & soya ***".',
#   'report_date': '20180620',
#   'classification': 'Class III',
#   'openfda': {},
#   'recalling_firm': 'Yukon Jackson',
#   'recall_number': 'F-1578-2018',
#   'initial_firm_notification': 'Visit',
#   'product_type': 'Food',
#   'event_id': '80233',
#   'termination_date': '20180625',
#   'recall_initiation_date': '20180525',
#   'postal_code': '98134-2139',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'status': 'Terminated'},
#  {'country': 'United States',
#   'city': 'Brooklyn',
#   'address_1': '47 Bridgewater St # 57',
#   'reason_for_recall': 'Product contains dried peaches, but front labeling of product stated dried plums',
#   'address_2': '',
#   'product_quantity': 'unknown',
#   'code_info': 'UPC CODE: 6868978724496  BEST BEFORE: 11/15/2021',
#   'center_classification_date': '20200424',
#   'distribution_pattern': 'Unknown',
#   'state': 'NY',
#   'product_description': 'XinXing Dried Plum, Net Wt. 5.3 oz.(150g)',
#   'report_date': '20200506',
#   'classification': 'Class III',
#   'openfda': {},
#   'recalling_firm': 'Rong Shing Trading NY Inc',
#   'recall_number': 'F-0921-2020',
#   'initial_firm_notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#   'product_type': 'Food',
#   'event_id': '85364',
#   'termination_date': '20210318',
#   'recall_initiation_date': '20200401',
#   'postal_code': '11222-3820',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'status': 'Terminated'},
#  {'country': 'United States',
#   'city': 'Tipp City',
#   'address_1': '320 N 2nd St',
#   'reason_for_recall': 'The firm stated that the product contains undeclared allergens.',
#   'address_2': '',
#   'product_quantity': '480/20 ib cases',
#   'code_info': 'Product #29973B  Code Dates: 10/20/2016, 11/8/2016, 11/9/2016 & 01/12/2017.',
#   'center_classification_date': '20170605',
#   'distribution_pattern': 'Product was sent to one manufacturer in MI',
#   'state': 'OH',
#   'product_description': 'Honey Bourbon Pecans Net Wt. 20 lb. (9.088g) Mfg. By: Trophy Nut Co. Tipp City, OH 45371',
#   'report_date': '20170614',
#   'classification': 'Class II',
#   'openfda': {},
#   'recalling_firm': 'Trophy Nut Co Inc',
#   'recall_number': 'F-2326-2017',
#   'initial_firm_notification': 'Letter',
#   'product_type': 'Food',
#   'event_id': '77213',
#   'termination_date': '20180213',
#   'recall_initiation_date': '20170505',
#   'postal_code': '45371',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'status': 'Terminated'},
#  {'country': 'United States',
#   'city': 'Jessup',
#   'address_1': '7971 Tarbay Dr',
#   'reason_for_recall': 'Possible contamination with Listeria monocytogenes.',
#   'address_2': '',
#   'product_quantity': '128 units',
#   'code_info': 'Lot 02332101',
#   'center_classification_date': '20150109',
#   'distribution_pattern': 'NJ, NY, OH, PA, RI, VA',
#   'state': 'MD',
#   'product_description': 'Gourmet Mix Fruit Delight Net Wt. 64 oz. (1814g) Best If Enjoyed By: 12/03/14, Dist. By: Wegmans Food Markets, Inc., Rochester, NY 14603 UPC 077890241516',
#   'report_date': '20150121',
#   'classification': 'Class I',
#   'openfda': {},
#   'recalling_firm': 'Del Monte Fresh Produce NA, Inc',
#   'recall_number': 'F-0777-2015',
#   'initial_firm_notification': 'Press Release',
#   'product_type': 'Food',
#   'event_id': '69983',
#   'termination_date': '20150428',
#   'more_code_info': '',
#   'recall_initiation_date': '20141209',
#   'postal_code': '20794-9416',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'status': 'Terminated'},
#  {'status': 'Terminated',
#   'city': 'Monterey',
#   'state': 'CA',
#   'country': 'United States',
#   'classification': 'Class I',
#   'openfda': {},
#   'product_type': 'Food',
#   'event_id': '89381',
#   'recalling_firm': 'Dole Fresh Vegetables Inc',
#   'address_1': '2959 Salinas Hwy',
#   'address_2': '',
#   'postal_code': '93940-6400',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'initial_firm_notification': 'Telephone',
#   'distribution_pattern': 'Canada: AB, BC, NB, ON, QC, Sk; United States: AL, AZ, CA, CO, CT, FL, GA, HI, IA, ID, IL, IN, KS, KY, LA, MA, MD, MI, MN, MO, MS, NC, ND, NE, NV, NY, OH, OK, OR, PA, SC, TN, TX, UT, VA, WA, WI',
#   'recall_number': 'F-0757-2022',
#   'product_description': 'Marketside 12oz Classic Salad  UPC:6-81131-32894-4  SKU: 3107',
#   'product_quantity': '',
#   'reason_for_recall': 'Harvest equipment used in harvesting raw iceberg lettuce was tested by  Dole and found to contain Listeria monocytogenes.',
#   'recall_initiation_date': '20220106',
#   'center_classification_date': '20220222',
#   'termination_date': '20220322',
#   'report_date': '20220302',
#   'code_info': 'Product codes beginning with B - Best by Dates of December 23, 2021 through January 8, 2022.',
#   'more_code_info': ''},
#  {'country': 'United States',
#   'city': 'Tucker',
#   'address_1': '3301 Montreal Industrial Way',
#   'reason_for_recall': 'Undeclared Allergen; Peanuts.',
#   'address_2': '',
#   'product_quantity': '577 cases (108 frozen pucks per case)',
#   'code_info': 'CSM Item Code: 31566200, Lot code: 5AF 1411901030',
#   'center_classification_date': '20150312',
#   'distribution_pattern': 'AL, GA, FL, IL, IN, MA, MD, MI, NJ, NY, NV, OH, PA and VA.',
#   'state': 'GA',
#   'product_description': 'TranSmart Raspberry Filled frozen unbaked cookie dough, 108/1.75 oz. units, CSM Bakery Products, 3301 Montreal Industrial Way Tucker, GA 30084..',
#   'report_date': '20150318',
#   'classification': 'Class I',
#   'openfda': {},
#   'recalling_firm': 'CSM Bakery Products NA-Atlanta Frozen',
#   'recall_number': 'F-1415-2015',
#   'initial_firm_notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#   'product_type': 'Food',
#   'event_id': '68761',
#   'termination_date': '20150326',
#   'recall_initiation_date': '20140626',
#   'postal_code': '30084-5211',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'status': 'Terminated'},
#  {'country': 'United States',
#   'city': 'Minneapolis',
#   'address_1': '33 S 6th St',
#   'reason_for_recall': 'Shipping container from CA to HI was not held at proper temperature which could cause food items to be contaminated with spoilage organisms or pathogens',
#   'address_2': '',
#   'product_quantity': '2652 retail units total',
#   'code_info': 'All product purchased at  Target store T2780, Honolulu, HI from March 23 through March 27, 2018.',
#   'center_classification_date': '20180503',
#   'distribution_pattern': 'HI',
#   'state': 'MN',
#   'product_description': 'Market Pantry Vanilla Ice Cream 128oz    UPC: 85239014943    Target item number: 288-7-307',
#   'report_date': '20180509',
#   'classification': 'Class II',
#   'openfda': {},
#   'recalling_firm': 'Target Corporation',
#   'recall_number': 'F-1328-2018',
#   'initial_firm_notification': 'Telephone',
#   'product_type': 'Food',
#   'event_id': '79663',
#   'termination_date': '20180503',
#   'recall_initiation_date': '20180327',
#   'postal_code': '55402-3601',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'status': 'Terminated'},
#  {'country': 'United States',
#   'city': 'Kent City',
#   'address_1': '16171 Fruit Ridge Ave',
#   'reason_for_recall': 'Nyblad Orchards Inc. initiated a voluntary recall of multiple varieties of whole fresh apples due to potential contamination with Listeria monocytogenes.',
#   'address_2': '',
#   'product_quantity': '5278 units shipped',
#   'code_info': 'NOI LOT #163, #164, #165, #166, #167, #168, #169, #159, #160, #173, #174.  These are on all plastic bag enclosures, mesh labels, and case labels for every pack.',
#   'center_classification_date': '20180124',
#   'distribution_pattern': 'Domestic: Michigan    Foreign/VA/DOD: None',
#   'state': 'MI',
#   'product_description': 'Golden delicious whole fresh apples,   Apple Ridge 5lb, 2-3/4  apples, packaged in red net mesh bags  "\t3lb, 2-1/2  apples, packaged in poly bags  "\t2lb, 2-1/2  apples, packaged in poly bags  "\t45ct individual apples on trays with re-useable plastic container boxes  "\t50ct, individual apples on trays with re-useable plastic container boxes  "\t55ct, individual apples on trays with re-useable plastic container boxes  "\t60ct  individual apples on trays with re-useable plastic container boxes  "\t78ct individual apples on trays with re-useable plastic container boxes  "\t50ct, individual apples on trays in cardboard tray  boxes  "\t55ct, individual apples on trays in cardboard tray  boxes',
#   'report_date': '20180117',
#   'classification': 'Class I',
#   'openfda': {},
#   'recalling_firm': 'Nyblad Orchards',
#   'recall_number': 'F-0616-2018',
#   'initial_firm_notification': 'Telephone',
#   'product_type': 'Food',
#   'event_id': '78793',
#   'termination_date': '20180406',
#   'more_code_info': '',
#   'recall_initiation_date': '20171214',
#   'postal_code': '49330-9752',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'status': 'Terminated'},
#  {'country': 'United States',
#   'city': 'Lenexa',
#   'address_1': '10001 Industrial Blvd',
#   'reason_for_recall': 'Sharp edges were observed on several of the cans which have the potential of causing cuts on the mouths of consumers who use the product.',
#   'address_2': '',
#   'product_quantity': '766,271 Cases Total',
#   'code_info': 'Oct 08 18 LXC',
#   'center_classification_date': '20180307',
#   'distribution_pattern': 'Distributed to retail stores in AR, IA, IL, KS, MO, and NE.',
#   'state': 'KS',
#   'product_description': 'Grape Fanta, Grape Flavored Soda, 12 oz (355 mL) cans, packed in 12 packs, Canned under the authority of the Coca-Cola Company, Atlanta, GA',
#   'report_date': '20180314',
#   'classification': 'Class II',
#   'openfda': {},
#   'recalling_firm': 'Heartland Coca-Cola Bottling Company',
#   'recall_number': 'F-0894-2018',
#   'initial_firm_notification': 'Letter',
#   'product_type': 'Food',
#   'event_id': '79216',
#   'termination_date': '20180705',
#   'recall_initiation_date': '20180212',
#   'postal_code': '66215-1209',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'status': 'Terminated'},
#  {'status': 'Ongoing',
#   'city': 'Nof Ha-Galil',
#   'state': '',
#   'country': 'Israel',
#   'classification': 'Class I',
#   'openfda': {},
#   'product_type': 'Food',
#   'event_id': '90105',
#   'recalling_firm': 'ELITE CONFECTIONERY LTD',
#   'address_1': 'Nazareth-Ilit',
#   'address_2': "5, Gilbo'A",
#   'postal_code': '',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'initial_firm_notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#   'distribution_pattern': 'Distributed in the US nationwide',
#   'recall_number': 'F-1233-2022',
#   'product_description': 'ELITE MILK CHOCOLATE COATED RICE CAKES  UPC:815871011884\tNET WT 2.47OZ (70 g)',
#   'product_quantity': 'unknown',
#   'reason_for_recall': 'Potential contamination with Salmonella',
#   'recall_initiation_date': '20220428',
#   'center_classification_date': '20220604',
#   'report_date': '20220615',
#   'code_info': 'All lots',
#   'more_code_info': ''},
#  {'country': 'United States',
#   'city': 'Kapaa',
#   'address_1': '5915 Olohena Rd',
#   'reason_for_recall': 'Candy was made using carob powder that is currently under recall by the direct supplier due to potential Salmonella contamination.',
#   'address_2': 'Unit H',
#   'product_quantity': 'All',
#   'code_info': 'UPC for single truffles: 11386711886    No lot codes or expiry dates',
#   'center_classification_date': '20140825',
#   'distribution_pattern': 'HI only',
#   'state': 'HI',
#   'product_description': 'Tiny Isle Chocolate Truffles Macadamia Nut: Gluten Free, Raw, Vegan; individual 1 oz. candies,    Tiny Isle  5915 Olohena Road, Unit H  Kapaa, HI 96746',
#   'report_date': '20140903',
#   'classification': 'Class I',
#   'openfda': {},
#   'recalling_firm': 'Florimont, Inc.',
#   'recall_number': 'F-2387-2014',
#   'initial_firm_notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#   'product_type': 'Food',
#   'event_id': '68994',
#   'termination_date': '20141104',
#   'recall_initiation_date': '20140725',
#   'postal_code': '96746-7709',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'status': 'Terminated'},
#  {'country': 'United States',
#   'city': 'Ventura',
#   'address_1': '675 E Santa Clara St Unit 2087',
#   'reason_for_recall': 'Potential Listeria monocytogenes contamination.',
#   'address_2': '',
#   'product_quantity': '400 cases (total)',
#   'code_info': 'Best By: March 17th 2017, March 18th 2017, March 19th 2017, March 20th 2017',
#   'center_classification_date': '20170224',
#   'distribution_pattern': 'U.S. distribution to the following; CA, NY.    No foreign distribution.',
#   'state': 'CA',
#   'product_description': "foxy's california pistachio  1 Pint",
#   'report_date': '20170308',
#   'classification': 'Class I',
#   'openfda': {},
#   'recalling_firm': 'Altijira Murray Products, LLC',
#   'recall_number': 'F-1540-2017',
#   'initial_firm_notification': 'Press Release',
#   'product_type': 'Food',
#   'event_id': '76035',
#   'termination_date': '20170330',
#   'more_code_info': '',
#   'recall_initiation_date': '20161220',
#   'postal_code': '93002-7115',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'status': 'Terminated'},
#  {'country': 'United States',
#   'city': 'Sebastopol',
#   'address_1': '9141 Green Valley Rd',
#   'reason_for_recall': 'Manzana Products Co. is initiating a recall of three varieties of apple sauce after receiving customer complaints or finding small pieces of glass in the product.',
#   'address_2': '',
#   'product_quantity': '70,157 jars',
#   'code_info': 'ALL CODES  Through AUG 08, 2018',
#   'center_classification_date': '20170320',
#   'distribution_pattern': 'Nationwide.',
#   'state': 'CA',
#   'product_description': "Trader Joe's First Crush Unsweetened Gravenstein Apple Sauce;   24 oz. glass jar.  Best Before date stamped on top of lid.    UPC:00015905     Distributed by Trader Joe's, Monrovia, CA",
#   'report_date': '20170329',
#   'classification': 'Class II',
#   'openfda': {},
#   'recalling_firm': 'Manzana Products Co.,  Inc.',
#   'recall_number': 'F-1643-2017',
#   'initial_firm_notification': 'Telephone',
#   'product_type': 'Food',
#   'event_id': '76589',
#   'termination_date': '20190529',
#   'more_code_info': '',
#   'recall_initiation_date': '20170224',
#   'postal_code': '95472-2245',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'status': 'Terminated'},
#  {'country': 'United States',
#   'city': 'City Of Industry',
#   'address_1': '13260 Temple Ave',
#   'reason_for_recall': 'Health One Pharmaceuticals is recalling dietary supplements due to significant violations of the cGMP regulations for dietary supplements.',
#   'address_2': '',
#   'product_quantity': '1035 units',
#   'code_info': '8520',
#   'center_classification_date': '20150330',
#   'distribution_pattern': 'Nationwide in US: CA, TN, WA, ID,     and worldwide:  Hong Kong, Vietnam, China, Singapore',
#   'state': 'CA',
#   'product_description': 'EST -700 Calcium',
#   'report_date': '20150408',
#   'classification': 'Class II',
#   'openfda': {},
#   'recalling_firm': 'Health One Pharmaceuticals Inc',
#   'recall_number': 'F-1681-2015',
#   'initial_firm_notification': 'Letter',
#   'product_type': 'Food',
#   'event_id': '70344',
#   'termination_date': '20150331',
#   'recall_initiation_date': '20150204',
#   'postal_code': '91746-1511',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'status': 'Terminated'},
#  {'country': 'United States',
#   'city': 'Coloma',
#   'address_1': '4145 Coloma Rd',
#   'reason_for_recall': 'Potential for adulteration - elevated mold, yeast, and coliform counts',
#   'address_2': '',
#   'product_quantity': '146,220 lbs. Total',
#   'code_info': 'Lot Codes: 15190  15191  15196  15198  15200  15201  15202  15203  15204  15205  15212  15215  43145  43146  43147  43148  43149  43150  43151  43152  43153  43155  43156  43157  43158  43159  43160  43161  43162  43163  43164  43165  43166  43167  43168  43169  43170  43171  43172  43173  43174  43175  43176  43177  43178  43179  43180  43181  43182  43183  43184  43583  43584  43585  43586  43587  43588  43589  43590  43591  43592  43593  43594  43595  43596  43597  43598  43599  43600  43601  43602  43603',
#   'center_classification_date': '20150909',
#   'distribution_pattern': 'Domestic: MI, IN, IL, WI, MO, NE, OH    Foreign: Canada  DOD/VA: None',
#   'state': 'MI',
#   'product_description': 'Red Tart Pitted Cherries, Straight Packed (No Sugar),  5 lbs. bulk pails, 30 lbs, in bulk pails',
#   'report_date': '20150916',
#   'classification': 'Class II',
#   'openfda': {},
#   'recalling_firm': 'Coloma Frozen Foods, Inc.',
#   'recall_number': 'F-3091-2015',
#   'initial_firm_notification': 'Letter',
#   'product_type': 'Food',
#   'event_id': '71948',
#   'termination_date': '20160428',
#   'recall_initiation_date': '20150807',
#   'postal_code': '49038-8967',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'status': 'Terminated'},
#  {'country': 'United States',
#   'city': 'Colonial Heights',
#   'address_1': '15900 Sabra Way',
#   'reason_for_recall': 'Michigan Dept. of Agriculture collected a sample of Sabra Hummus that came up positive for L. Monocytogenes.  Baltimore District is  working with VDACS to investigate.',
#   'address_2': '',
#   'product_quantity': '9312 Cases',
#   'code_info': 'UPC/SKU    040822017497 / 301290',
#   'center_classification_date': '20150428',
#   'distribution_pattern': 'The product was distributed nationwide.',
#   'state': 'VA',
#   'product_description': 'Sabra Classic Hummus, 17oz Six Pack UPC 040822017497 / 301290  Sabra Dipping Co. LLC, White Plains, NY',
#   'report_date': '20150506',
#   'classification': 'Class I',
#   'openfda': {},
#   'recalling_firm': 'Sabra Dipping Company, LLC',
#   'recall_number': 'F-2085-2015',
#   'initial_firm_notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#   'product_type': 'Food',
#   'event_id': '70934',
#   'termination_date': '20150826',
#   'more_code_info': '',
#   'recall_initiation_date': '20150407',
#   'postal_code': '23834-5935',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'status': 'Terminated'},
#  {'country': 'United States',
#   'city': 'Brenham',
#   'address_1': '1101 S Blue Bell Rd',
#   'reason_for_recall': 'Five patients who were treated in a single hospital in Kansas were infected with one of four rare strains of Listeria monocytogenes.',
#   'address_2': '',
#   'product_quantity': '503,367 units',
#   'code_info': 'all lot codes within expiry',
#   'center_classification_date': '20150619',
#   'distribution_pattern': 'FL, GA, SC, NC, VA, OH, KY, TN, AL, MS, IN, IL, MT, AR, LA, TX, Ok, KS, NM, CO, WY, AZ, NV and Bermuda, Belize, Saudia Arabia, Yemen, Oman, UAE, Qatar, Egypt, Jordan, Kuwait, Dominican Republic, Panama, Turks and Caicos, Haiti, Trinadad and Tobago, Puerto Rico, Chile, Peru, China, Mexico, Philippines, Tortola, St. Thomas and St. Croix, Anguilla, St, Kitts and Nevis, Montserrat, and Dominica',
#   'state': 'TX',
#   'product_description': 'Blue Bell Ice Cream Blueberry Cheesecake Still a 1/2 Gal (2 QTS)',
#   'report_date': '20150701',
#   'classification': 'Class I',
#   'openfda': {},
#   'recalling_firm': 'Blue Bell Creameries, L.P.',
#   'recall_number': 'F-2543-2015',
#   'initial_firm_notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#   'product_type': 'Food',
#   'event_id': '70738',
#   'termination_date': '20161103',
#   'more_code_info': '',
#   'recall_initiation_date': '20150313',
#   'postal_code': '77833-4413',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'status': 'Terminated'},
#  {'country': 'United States',
#   'city': 'Gardena',
#   'address_1': '310 W Alondra Blvd',
#   'reason_for_recall': 'Potential Listeria monocytogenes contamination.',
#   'address_2': '',
#   'product_quantity': '',
#   'code_info': 'Lot #040115-050616',
#   'center_classification_date': '20160805',
#   'distribution_pattern': 'U.S. distribution nationwide.     No foreign distribution.',
#   'state': 'CA',
#   'product_description': 'Integrated Food Service  Turkey Breast & Cheese Sandwich  on a Whole Grain French Roll  Code #C16001/160001',
#   'report_date': '20160817',
#   'classification': 'Class I',
#   'openfda': {},
#   'recalling_firm': "Let's Do Lunch, Inc.",
#   'recall_number': 'F-1892-2016',
#   'initial_firm_notification': 'Letter',
#   'product_type': 'Food',
#   'event_id': '74243',
#   'termination_date': '20170531',
#   'more_code_info': '',
#   'recall_initiation_date': '20160523',
#   'postal_code': '90248-2423',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'status': 'Terminated'},
#  {'country': 'United States',
#   'city': 'Saint Petersburg',
#   'address_1': '4711 34th St N Unit F',
#   'reason_for_recall': 'Products may be contaminated with  Listeria monocytogenes.',
#   'address_2': '',
#   'product_quantity': '8286 tubs',
#   'code_info': '"8/29/2017 - 10/11/2018"',
#   'center_classification_date': '20181113',
#   'distribution_pattern': 'US Consignees only. No foreign nor government consignees.',
#   'state': 'FL',
#   'product_description': 'Vanilla Bean Ice Cream, 3 gallons',
#   'report_date': '20181121',
#   'classification': 'Class I',
#   'openfda': {},
#   'recalling_firm': 'Working Cow Homemade Inc.',
#   'recall_number': 'F-0441-2019',
#   'initial_firm_notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#   'product_type': 'Food',
#   'event_id': '81156',
#   'termination_date': '20190426',
#   'more_code_info': '',
#   'recall_initiation_date': '20180928',
#   'postal_code': '33714-3060',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'status': 'Terminated'},
#  {'country': 'United States',
#   'city': 'Lakeland',
#   'address_1': '3300 Publix Corporate Pkwy',
#   'reason_for_recall': 'Maplehurst Deli-Bake South Inc. the cake supplier notified Publix Super market of a contamination with Listeria Monocytogenes on 11/15/2012.',
#   'address_2': '',
#   'product_quantity': '',
#   'code_info': 'Recalled products were distributed from November 11, 2012 through November 15, 2012.',
#   'center_classification_date': '20130313',
#   'distribution_pattern': 'Florida',
#   'state': 'FL',
#   'product_description': 'Publix 7 inch Cookies Cream Layer Cake  Scale ID Number * 002-16466-00000 *The last five digits of the scale ID number contain the unit price. For example $4.99 would have the last five digits ending 00499.',
#   'report_date': '20130320',
#   'classification': 'Class I',
#   'openfda': {},
#   'recalling_firm': 'Publix Super Markets, Inc.',
#   'recall_number': 'F-1146-2013',
#   'initial_firm_notification': 'E-Mail',
#   'product_type': 'Food',
#   'event_id': '64493',
#   'termination_date': '20130517',
#   'more_code_info': '',
#   'recall_initiation_date': '20121115',
#   'postal_code': '33811-3311',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'status': 'Terminated'},
#  {'country': 'United States',
#   'city': 'Coldwater',
#   'address_1': '5377 Highway 306',
#   'reason_for_recall': 'Undeclared allergen: Wheat  Undeclared colors: Yellow #5 and #6.',
#   'address_2': '',
#   'product_quantity': 'Unknown',
#   'code_info': 'Products are not coded.',
#   'center_classification_date': '20200417',
#   'distribution_pattern': 'Distributed in the states of AL, AR, FL, GA, IL, LA, MS, OK, and TX.',
#   'state': 'MS',
#   'product_description': 'Southern Sisters Gourmet Cheddar Garlic Biscuits, Net Wt 16 oz (453.6 g)',
#   'report_date': '20200401',
#   'classification': 'Class II',
#   'openfda': {},
#   'recalling_firm': 'Southern Sisters Gourmet',
#   'recall_number': 'F-0913-2020',
#   'initial_firm_notification': 'Telephone',
#   'product_type': 'Food',
#   'event_id': '84863',
#   'termination_date': '20210216',
#   'more_code_info': '',
#   'recall_initiation_date': '20200128',
#   'postal_code': '38618-5119',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'status': 'Terminated'},
#  {'country': 'United States',
#   'city': 'Seattle',
#   'address_1': '4103 2nd Ave S',
#   'reason_for_recall': 'Stir Fry Kit product is recalled due to possible contamination with Listeria monocytogenes. The broccoli used in processing this item has been recalled by vendor Mann Packing of Salinas, California.',
#   'address_2': '',
#   'product_quantity': '42 cases',
#   'code_info': 'Pack Date: 10/13/2017.  Use By: 10/20/2017',
#   'center_classification_date': '20171113',
#   'distribution_pattern': 'distributed in Alaska, Idaho, Montana, Oregon, and Washington',
#   'state': 'WA',
#   'product_description': 'Stir Fry Kit,  Alaska Carrot, 1 x 11 lb. per case, UPC 45009 85749 1    The ingredient: Green cabbage, yellow onion, broccoli florette, carrot plugs.',
#   'report_date': '20171108',
#   'classification': 'Class I',
#   'openfda': {},
#   'recalling_firm': 'Triple B Corporation',
#   'recall_number': 'F-0163-2018',
#   'initial_firm_notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#   'product_type': 'Food',
#   'event_id': '78335',
#   'termination_date': '20171206',
#   'recall_initiation_date': '20171020',
#   'postal_code': '98134-2305',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'status': 'Terminated'},
#  {'country': 'United States',
#   'city': 'Saint Petersburg',
#   'address_1': '4711 34th St N Unit F',
#   'reason_for_recall': 'Products may be contaminated with  Listeria monocytogenes.',
#   'address_2': '',
#   'product_quantity': '42 tubs',
#   'code_info': '"8/29/2017 - 10/11/2018"',
#   'center_classification_date': '20181113',
#   'distribution_pattern': 'US Consignees only. No foreign nor government consignees.',
#   'state': 'FL',
#   'product_description': 'JY Spiderman Ice Cream, 3 gallons',
#   'report_date': '20181121',
#   'classification': 'Class I',
#   'openfda': {},
#   'recalling_firm': 'Working Cow Homemade Inc.',
#   'recall_number': 'F-0583-2019',
#   'initial_firm_notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#   'product_type': 'Food',
#   'event_id': '81156',
#   'termination_date': '20190426',
#   'more_code_info': '',
#   'recall_initiation_date': '20180928',
#   'postal_code': '33714-3060',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'status': 'Terminated'},
#  {'country': 'United States',
#   'city': 'Monterey',
#   'address_1': '2959 Salinas Hwy',
#   'reason_for_recall': 'Green Walnuts from a tree dropped into spinach as it was being tractored away from the harvested field. Walnuts were discovered on the Dole spinach processing line',
#   'address_2': '',
#   'product_quantity': '150 cartons (6 x 6 oz bags per carton)',
#   'code_info': 'Bag Code                        Expiration Date  B2311020  9/4/2014   B23110211 9/4/2014  B2311022  9/4/2014  B2311023  9/4/2014  B2311024  9/4/2014  B2311025  9/4/2014.',
#   'center_classification_date': '20140915',
#   'distribution_pattern': 'One distribution center in AZ and retail stores in AZ, NM and NV.',
#   'state': 'CA',
#   'product_description': 'Dole Baby Spinach:  Thoroughly Washed, Preservative Free, All natural  Net W.t6 oz. bag;  SKU 323  Perishable, keep refrigerated.  UPC 071430009642;    Dole Fresh Vegetables  Monterey, CA  93940',
#   'report_date': '20140924',
#   'classification': 'Class I',
#   'openfda': {},
#   'recalling_firm': 'Dole Fresh Vegetables Inc',
#   'recall_number': 'F-2441-2014',
#   'initial_firm_notification': 'Telephone',
#   'product_type': 'Food',
#   'event_id': '69128',
#   'termination_date': '20140917',
#   'more_code_info': '',
#   'recall_initiation_date': '20140827',
#   'postal_code': '93940-6400',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'status': 'Terminated'},
#  {'country': 'United States',
#   'city': 'Spokane Valley',
#   'address_1': '9608 E Montgomery Ave Ste 5',
#   'reason_for_recall': 'The recalling firm was notified that raw materials used in producing the ice cream products have the potential to be contaminated with Listeria monocytogenes',
#   'address_2': '',
#   'product_quantity': 'Approx 3 gallons',
#   'code_info': 'All codes manufactured from January 1, 2014 - December 15, 2014. ("MMDD" and "XXXX"-Snoqualmie Gourmet Ice Cream Code)',
#   'center_classification_date': '20150211',
#   'distribution_pattern': 'Washington and Idaho ice cream scoop shops and restaurants.',
#   'state': 'WA',
#   'product_description': 'Pear Sorbet; Bulk product is labeled with flavor name and date code, which is affixed to the plastic container (1, 1.5 and 3 gallon).',
#   'report_date': '20150218',
#   'classification': 'Class I',
#   'openfda': {},
#   'recalling_firm': 'Numbskull LLC',
#   'recall_number': 'F-1182-2015',
#   'initial_firm_notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#   'product_type': 'Food',
#   'event_id': '70150',
#   'termination_date': '20150223',
#   'recall_initiation_date': '20141223',
#   'postal_code': '99206-4162',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'status': 'Terminated'},
#  {'country': 'United States',
#   'city': 'Moosic',
#   'address_1': '591 Rocky Glen Road',
#   'reason_for_recall': "A recall was initiated as a result of an undeclared sugar ingredient in the labeling used for Jennies' Dutch Chocolate Macaroons.",
#   'address_2': '',
#   'product_quantity': '31 cases',
#   'code_info': 'Expiration dates 12/1/13 and 1/13/14.',
#   'center_classification_date': '20130809',
#   'distribution_pattern': 'PA, GA, NH.',
#   'state': 'PA',
#   'product_description': 'individual 2 oz chocolate macaroons packaged in plastic wrapper labeled as " Jennies DUTCH CHOCOLATE MACAROON, 2 oz. Red Mill Farms, Inc., Brooklyn, NY".',
#   'report_date': '20130821',
#   'classification': 'Class II',
#   'openfda': {},
#   'recalling_firm': 'Red Mill Farms',
#   'recall_number': 'F-1796-2013',
#   'initial_firm_notification': 'E-Mail',
#   'product_type': 'Food',
#   'event_id': '65754',
#   'termination_date': '20141020',
#   'more_code_info': '',
#   'recall_initiation_date': '20130320',
#   'postal_code': '18507',
#   'voluntary_mandated': 'Voluntary: Firm Initiated',
#   'status': 'Terminated'},
#  {'country': 'United States',
#   'city': 'Grand Rapids',
#   'address_1': '900 Hynes Ave SW',
#   'reason_for_recall': 'Savory Foods Inc. has initiated a voluntary recall due to the potential for contamination with Listeria monocytogenes.',
#   'address_2': '',
#   'product_quantity': '15 cases',
#   'code_info': '1.5 oz PEANUT BUTTER COOKIES, 80/case; Product Code/Lot Code: 16033',
#   'center_classification_date': '20160930',
#   'distribution_pattern': 'Domestic: Jackson, MI; Toledo, OH; Grand Rapids, MI; Urbana, OH; Hudsonville, MI; Columbus, OH; Lansdale, PA; and Charlton, MA.    No Foreign or DOD/VA',
#   'state': 'MI',
#   'product_description': '1.5 oz PEANUT BUTTER COOKIES, 80/case',
#   'report_date': '20161012',
#   'classification': 'Class I',
#   'openfda': {},
#   'recalling_firm': 'Savory Foods, Inc.',
#   'recall_number': 'F-2473-2016',
#   'initial_firm_notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#   'product_type': 'Food',
#   'event_id': '73353',
#   'termination_date': '20161028',
#   'recall_initiation_date': '20160211',
#   'postal_code': '49507-1076',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'status': 'Terminated'},
#  {'country': 'United States',
#   'city': 'Minneapolis',
#   'address_1': '2521 E Hennepin Ave',
#   'reason_for_recall': 'G.O. Fresh in Minnesota is voluntarily recalling specific cut items that contain cantaloupe, which has been recalled by DFI Marketing, Inc. due to potential Salmonella contamination.',
#   'address_2': '',
#   'product_quantity': '721 TOTAL CASES FOR ALL PRODUCTS',
#   'code_info': 'BEST BY 9/15/12 & 9/16/12,',
#   'center_classification_date': '20121011',
#   'distribution_pattern': 'Minnesota, Iowa, North Dakota and Wisconsin',
#   'state': 'MN',
#   'product_description': 'SYSCO Imperial\t6520795\t1/5# FRUIT MIX CHUNKS 3/4"\t130249 & 130250\tBEST BY 9/15/12 & 9/16/12, UPC# 1007 4865393314.',
#   'report_date': '20121017',
#   'classification': 'Class I',
#   'openfda': {},
#   'recalling_firm': 'G.O. Fresh',
#   'recall_number': 'F-0091-2013',
#   'initial_firm_notification': 'Letter',
#   'product_type': 'Food',
#   'event_id': '63267',
#   'termination_date': '20130214',
#   'recall_initiation_date': '20120913',
#   'postal_code': '55413-2911',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'status': 'Terminated'},
#  {'country': 'United States',
#   'city': 'New York',
#   'address_1': '950 3rd Avenue, 21st Floor',
#   'reason_for_recall': 'Recalled whey powder was used in further production of numerous food products.',
#   'address_2': '',
#   'product_quantity': '216 Cases (10 x 1.lb. pouches per case)',
#   'code_info': '2280703   Best By 4/3/2019',
#   'center_classification_date': '20180813',
#   'distribution_pattern': 'CA, CO, UT, WA, GA, TX',
#   'state': 'NY',
#   'product_description': 'Homestyle Italian Seasoned Croutons:  1 lb. foil pouch  Item # 74384              Sugar Foods Corporation  6190 E. Slauson Ave.  Los Angeles, CA 90047',
#   'report_date': '20180808',
#   'classification': 'Class II',
#   'openfda': {},
#   'recalling_firm': 'Sugar Foods Corporation Inc',
#   'recall_number': 'F-1804-2018',
#   'initial_firm_notification': 'Telephone',
#   'product_type': 'Food',
#   'event_id': '80580',
#   'termination_date': '20180918',
#   'recall_initiation_date': '20180720',
#   'postal_code': '10022',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'status': 'Terminated'},
#  {'country': 'United States',
#   'city': 'Amityville',
#   'address_1': '9500 New Horizons Blvd',
#   'reason_for_recall': 'The finished dietary supplement product was manufactured with ingredients subsequently found to be contaminated with chloramphenicol, an antibiotic, at levels above 0.3 ppb.  The supplier, Specialty Enzymes & Biotechnologies, recalled the raw materials and notified the recipients.  Subsequent private laboratory testing of the finished product revealed levels of chloramphenicol above 0.3 ppb.',
#   'address_2': '',
#   'product_quantity': '1495 bottles',
#   'code_info': 'Lot Number 1256074',
#   'center_classification_date': '20131218',
#   'distribution_pattern': 'New York',
#   'state': 'NY',
#   'product_description': 'UT-Fem¿ FOR WOMEN, urinary tract SOLUTION, Dietary Supplement, 42 Vegetable Capsules, Product No. 110403, UPC 7 98304 24865 4 -- Manufactured for: Global Quality Health Inc.',
#   'report_date': '20131225',
#   'classification': 'Class II',
#   'openfda': {},
#   'recalling_firm': 'Global Health Laboratories, LLC',
#   'recall_number': 'F-1105-2014',
#   'initial_firm_notification': 'Letter',
#   'product_type': 'Food',
#   'event_id': '66765',
#   'termination_date': '20170308',
#   'recall_initiation_date': '20131107',
#   'postal_code': '11701-1155',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'status': 'Terminated'},
#  {'country': 'United States',
#   'city': 'Beaverton',
#   'address_1': '15570 SW Jenkins Road',
#   'reason_for_recall': 'The recalled products are potentially contaminated with Listeria monocytogenes.',
#   'address_2': '',
#   'product_quantity': '',
#   'code_info': 'Use by dates 10/10/13 - 11/29/13.',
#   'center_classification_date': '20131224',
#   'distribution_pattern': 'Distribution was made to AL, AR, AZ, CA, CO, CT, DE, FL, GA, HI, IA, IL, IN, KS, KY, LA, MA, MD, ME, MI, MO, MS, NC, NE, NH, NJ, NM, NV, NY, OH, OK, OR, PA, SC, SD, TN, TX, VA, WI, WV AND WY.   Distribution was also made to Canada.',
#   'state': 'OR',
#   'product_description': "Tuna Salad, Formula PT.60 packaged under these labels:    -Essentail Everyday Tuna Salad packaged in 6/12-oz (UPC 041303820285) carton cases. Distributed by Supervalu Inc., Eden Prairie, MN.    -Reser's Gourmet Tuna Salad packaged in 2/5-lb carton cases.  Reser's Fine Foods, Inc., Beaverton, OR.  UPC 071117855067",
#   'report_date': '20140101',
#   'classification': 'Class I',
#   'openfda': {},
#   'recalling_firm': "Reser's Fine Foods, Inc.",
#   'recall_number': 'F-1216-2014',
#   'initial_firm_notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#   'product_type': 'Food',
#   'event_id': '66563',
#   'termination_date': '20170124',
#   'more_code_info': '',
#   'recall_initiation_date': '20131022',
#   'postal_code': '97006',
#   'voluntary_mandated': 'Voluntary: Firm Initiated',
#   'status': 'Terminated'},
#  {'country': 'United States',
#   'city': 'Tracy',
#   'address_1': '1820 North Macarthur Drive',
#   'reason_for_recall': 'Firm was notified by supplier that specific lots of "expo fresh" Roma tomatoes may be contaminated with Salmonella.',
#   'address_2': '',
#   'product_quantity': '45 / 25 Lb. Boxes',
#   'code_info': 'Packed on: 9/5/2014  Packed on: 9/6/2014',
#   'center_classification_date': '20141010',
#   'distribution_pattern': 'California, Arizona, Nevada, Washington',
#   'state': 'CA',
#   'product_description': 'CST Roma Tomatoes Whole Roma 1/25#  Origin: USA  Keep Refrigerated   UPC: 40000356942  Taylor Farms, Pacific, Tracy, CA 95376',
#   'report_date': '20141022',
#   'classification': 'Class I',
#   'openfda': {},
#   'recalling_firm': 'Taylor Farms Pacific Inc. (MacArthur Facility)',
#   'recall_number': 'F-0020-2015',
#   'initial_firm_notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#   'product_type': 'Food',
#   'event_id': '69252',
#   'termination_date': '20141015',
#   'recall_initiation_date': '20140912',
#   'postal_code': '95376-2831',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'status': 'Terminated'},
#  {'country': 'United States',
#   'city': 'Chicago',
#   'address_1': '2501 N Keeler Ave',
#   'reason_for_recall': 'Product may contain undeclared milk.',
#   'address_2': '',
#   'product_quantity': '2,550 lbs',
#   'code_info': 'Product #A96555; Lot #WN012117E',
#   'center_classification_date': '20170817',
#   'distribution_pattern': 'Nationwide, Mexico, Canada',
#   'state': 'IL',
#   'product_description': 'A96555, PREDUST X2, NET WT 50 LBS, Manufactured By: Newly Weds Foods, Inc., Chicago, IL 60639',
#   'report_date': '20170726',
#   'classification': 'Class II',
#   'openfda': {},
#   'recalling_firm': 'Newly Weds Foods Inc',
#   'recall_number': 'F-3116-2017',
#   'initial_firm_notification': 'Letter',
#   'product_type': 'Food',
#   'event_id': '77194',
#   'termination_date': '20190805',
#   'recall_initiation_date': '20170503',
#   'postal_code': '60639-2131',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'status': 'Terminated'},
#  {'country': 'United States',
#   'city': 'Canovanas',
#   'address_1': '81 Calle Autonomia',
#   'reason_for_recall': 'Undeclared allergens: wheat, soy, crustacean shellfish (crab), and yellow #5',
#   'address_2': '',
#   'product_quantity': '160',
#   'code_info': 'none',
#   'center_classification_date': '20121108',
#   'distribution_pattern': 'PR only. Product sold by the firm at retail.',
#   'state': 'PR',
#   'product_description': '"Alcapurria Jueyes" (Crab-filled fritters) - Food Service',
#   'report_date': '20121114',
#   'classification': 'Class II',
#   'openfda': {},
#   'recalling_firm': 'Fabrica Confecciones Soto, Inc.',
#   'recall_number': 'F-0655-2013',
#   'initial_firm_notification': 'Letter',
#   'product_type': 'Food',
#   'event_id': '63207',
#   'termination_date': '20170503',
#   'recall_initiation_date': '20120912',
#   'postal_code': '00729-3248',
#   'voluntary_mandated': 'Voluntary: Firm Initiated',
#   'status': 'Terminated'},
#  {'status': 'Ongoing',
#   'city': 'Kansas City',
#   'state': 'KS',
#   'country': 'United States',
#   'classification': 'Class I',
#   'openfda': {},
#   'product_type': 'Food',
#   'event_id': '90164',
#   'recalling_firm': "Liberty Fruit Co Inc DBA Carol's Cuts",
#   'address_1': '1251 Argentine Blvd',
#   'address_2': '',
#   'postal_code': '66105-1508',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'initial_firm_notification': 'Telephone',
#   'distribution_pattern': 'Distributed to food service locations in Kansas, Nebraska, Iowa, and Missouri.',
#   'recall_number': 'F-1159-2022',
#   'product_description': 'POTATO RUSSET QUARTERED 2/10# (01)10886810715115(10)0016086772 71511 Best if used by: 03/25/22, 03/29/22, 04/05/22, 04/06/22, 04/12/22, 04/16/22, 04/20/22, 04/23/22 Ingredients: Potato, Sodium Metabisulfite',
#   'product_quantity': '25,433 lbs (total)',
#   'reason_for_recall': 'Sodium metabisulfite not declared on product label.',
#   'recall_initiation_date': '20220506',
#   'center_classification_date': '20220603',
#   'report_date': '20220615',
#   'code_info': 'Best if used by: 03/25/22, 03/29/22, 04/05/22, 04/06/22, 04/12/22, 04/16/22, 04/20/22, 04/23/22 Product #: 71511',
#   'more_code_info': ''},
#  {'country': 'United States',
#   'city': 'Maspeth',
#   'address_1': '4880 Maspeth Ave',
#   'reason_for_recall': 'Product contains undeclared sulfites.',
#   'address_2': '',
#   'product_quantity': 'unknown',
#   'code_info': '0712  7/12/2019',
#   'center_classification_date': '20190329',
#   'distribution_pattern': 'CT, NY, NJ',
#   'state': 'NY',
#   'product_description': 'JOY GOL-GAPPA (PANI PURI) MASALA CONCENTRATE, NET WT 8 OZ (228g), UPC: 6 80617 60414 5',
#   'report_date': '20190320',
#   'classification': 'Class II',
#   'openfda': {},
#   'recalling_firm': 'JOY GOURMET FOODS LLC',
#   'recall_number': 'F-1215-2019',
#   'initial_firm_notification': 'Visit',
#   'product_type': 'Food',
#   'event_id': '82250',
#   'termination_date': '20200710',
#   'recall_initiation_date': '20190225',
#   'postal_code': '11378-2110',
# ...
#   'recalling_firm': 'Elegant Foods, LLC',
#   'address_1': '537 Atlas Ave',
#   'address_2': '',
#   'postal_code': '53714-3107',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'initial_firm_notification': 'Telephone',
#   'distribution_pattern': 'WI',
#   'recall_number': 'F-1032-2022',
#   'product_description': 'elegant foods Lemon Macaron, Case of 100.  537 Atlas Ave, Madison, WI  53714.',
#   'product_quantity': '41 cases',
#   'reason_for_recall': 'Macarons do not declare the following colors:  FD&C Blue #1, Blue #2, Red #3, Yellow #5, Yellow #6, Red #40.',
#   'recall_initiation_date': '20220323',
#   'center_classification_date': '20220502',
#   'report_date': '20220511',
#   'code_info': '213645A'},
#  {'country': 'United States',
#   'city': 'Coral Gables',
#   'address_1': '2655 S Le Jeune Rd Ste 1011',
#   'reason_for_recall': 'Products contain undeclared milk on finished product labeling',
#   'address_2': '',
#   'product_quantity': '8,651 12-ct cases',
#   'code_info': 'Lot Code (Exp date): 08212016 (08212016), 100116 (100116), 100122016 (100122016), 100216 (100216), 10302016 (10302016), 111316 (111316).',
#   'center_classification_date': '20160602',
#   'distribution_pattern': 'Product distributed nationwide an internationally to the following countries: Egypt, Bermuda, and United Arab Emirates',
#   'state': 'FL',
#   'product_description': 'Fruit Tartlets, Raspberry flavor, 9 - 0.56oz (16 g) tartlets - Net Wt. 5.1oz (145 g).  Manufactured in France.  Distributed by Ouhlala Gourmet Corp. dba Buddy Fruits, Coral Gables, FL',
#   'report_date': '20160608',
#   'classification': 'Class II',
#   'openfda': {},
#   'recalling_firm': 'Ouhlala Gourmet Llc',
#   'recall_number': 'F-1420-2016',
#   'initial_firm_notification': 'Letter',
#   'product_type': 'Food',
#   'event_id': '73670',
#   'recall_initiation_date': '20160120',
#   'postal_code': '33134-5803',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'status': 'Ongoing'},
#  {'country': 'United States',
#   'city': 'West des Moines',
#   'address_1': '5820 Westown Pkwy',
#   'reason_for_recall': 'Product contained an ingredient that tested positive for Salmonella.',
#   'address_2': '',
#   'product_quantity': '2,608 32 oz and other similar sizes; 4,367 8 oz and other similar sizes',
#   'code_info': 'Expiration date range between December 6, 2018 and January 11, 2019',
#   'center_classification_date': '20190206',
#   'distribution_pattern': 'Distributed to consumers in Iowa, Illinois, Missouri, Kansas, Nebraska, South Dakota, Minnesota and Wisconsin.',
#   'state': 'IA',
#   'product_description': 'HyVee brand Pumpkin-fluff -flavored cheese cakes packaged in the following ways:    1) Pumpkin-fluff Cheesecake, Net Wt. 7 OZ, HyVee West Des Moines, IA UPC 02 80148 XXXXX packaged in clear plastic containers;    2) Pumpkin-fluff Cheesecake Family Size, Net Wt. 32 OZ, HyVee West Des Moines, IA 02 80147 XXXXX, packaged in clear plastic containers',
#   'report_date': '20190213',
#   'classification': 'Class I',
#   'openfda': {},
#   'recalling_firm': 'Hy-Vee Stores Inc',
#   'recall_number': 'F-0826-2019',
#   'initial_firm_notification': 'Press Release',
#   'product_type': 'Food',
#   'event_id': '81904',
#   'termination_date': '20190211',
#   'more_code_info': '',
#   'recall_initiation_date': '20190104',
#   'postal_code': '50266-8223',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'status': 'Terminated'},
#  {'status': 'Ongoing',
#   'city': 'Orrville',
#   'state': 'OH',
#   'country': 'United States',
#   'classification': 'Class I',
#   'openfda': {},
#   'product_type': 'Food',
#   'event_id': '90255',
#   'recalling_firm': 'The JM Smucker Company LLC',
#   'address_1': '1 Strawberry Ln',
#   'address_2': '',
#   'postal_code': '44667-1241',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'initial_firm_notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#   'distribution_pattern': 'AK, AL, AR, AZ, CA, CO, CT, DE, FL, GA, HI, IA, ID, IL, IN, KS, KY, LA, MA, MD, ME, MI, MN, MO, MS, MT, NC, ND, NE, NH, NJ, NM, NV, NY, OH, OK, OR, PA, RI, SC, TN, TX, UT, VA, VT, WA, WI, WV, WY',
#   'recall_number': 'F-1112-2022',
#   'product_description': 'JIF NATURAL PEANUT BUTTER  packaged in 0.64oz and 96 count',
#   'product_quantity': '47918 cases total',
#   'reason_for_recall': 'Products are potentially contaminated with Salmonella.',
#   'recall_initiation_date': '20220520',
#   'center_classification_date': '20220601',
#   'report_date': '20220608',
#   'code_info': 'Lot codes: 1274425   2140425 UPC: 5150008058, 5150021889 Best By Date 06/28/22 - 02/14/23, 10/01/22 - 05/20/23'},
#  {'country': 'United States',
#   'city': 'Milwaukee',
#   'address_1': '726 S 12th St.',
#   'reason_for_recall': 'Garden-Fresh Foods is recalling various cut vegetables,  ready-to-eat salads, slaw, spread and dip products sold under various brands and code dates manufactured prior to November 06, 2013  because they may be contaminated with Listeria monocytogenes.',
#   'address_2': '',
#   'product_quantity': '919,616.31 total pounds, for all products',
#   'code_info': '0 11596 53050 5, 11/9/2013 - 11/11/2013;',
#   'center_classification_date': '20131218',
#   'distribution_pattern': 'IL, IN, MI, MN, MO, OH, PA, WI.',
#   'state': 'WI',
#   'product_description': "Martin's,\tOriental Cabbage Kit,\t1/10 lb.,\t\t0 11596 53050 5,\t11/9/2013 - 11/11/2013;",
#   'report_date': '20131225',
#   'classification': 'Class I',
#   'openfda': {},
#   'recalling_firm': 'Garden-Fresh Foods, Inc.',
#   'recall_number': 'F-0993-2014',
#   'initial_firm_notification': 'Press Release',
#   'product_type': 'Food',
#   'event_id': '66819',
#   'termination_date': '20151029',
#   'recall_initiation_date': '20131107',
#   'postal_code': '53204-1211',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'status': 'Terminated'},
#  {'country': 'United States',
#   'city': 'Deland',
#   'address_1': '1842 Patterson Ave Unit 8',
#   'reason_for_recall': 'Undeclared soy on product label',
#   'address_2': '',
#   'product_quantity': '29 gallons (309 bottles)',
#   'code_info': 'Best by date of 09/01/2016 or before',
#   'center_classification_date': '20151027',
#   'distribution_pattern': "Sold some to product to the U.S. Navy Exchange in Key West, Florida    Mainly distributed to Key West shops in Florida and Maryland.  Only the Kermit's Key Lime Ginger Wasabi Marinade was sent to Maryland customer.       Approximately 6% of sales are internet sales which went to customers nationwide",
#   'state': 'FL',
#   'product_description': "Kermit's Key Lime Cocktail Sauce, 12 oz, Key West, FL, UPC 007172006076 & 0802468905503",
#   'report_date': '20151104',
#   'classification': 'Class II',
#   'openfda': {},
#   'recalling_firm': 'Kermit, Inc.',
#   'recall_number': 'F-0101-2016',
#   'initial_firm_notification': 'Telephone',
#   'product_type': 'Food',
#   'event_id': '72272',
#   'termination_date': '20170302',
#   'recall_initiation_date': '20150915',
#   'postal_code': '32724-1953',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'status': 'Terminated'},
#  {'country': 'United States',
#   'city': 'Milwaukee',
#   'address_1': '726 S 12th St.',
#   'reason_for_recall': 'Garden-Fresh Foods is recalling various ready-to-eat salads, slaw, and dip products sold under various brands and codes because they may be contaminated with Listeria monocytogenes.',
#   'address_2': '',
#   'product_quantity': '1,159,754.46 total pounds, for all varieties',
#   'code_info': '0 11596 65047 0= 10/30/2013',
#   'center_classification_date': '20131202',
#   'distribution_pattern': 'CA, IL, IN, MA, MI,MN, MO, OH, PA, WI.',
#   'state': 'WI',
#   'product_description': 'Tropical Waldrof Salad Kit,  0 11596 65047 0,\t1/6.125 lb',
#   'report_date': '20131211',
#   'classification': 'Class I',
#   'openfda': {},
#   'recalling_firm': 'Garden-Fresh Foods, Inc.',
#   'recall_number': 'F-0621-2014',
#   'initial_firm_notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#   'product_type': 'Food',
#   'event_id': '66677',
#   'termination_date': '20140313',
#   'recall_initiation_date': '20131030',
#   'postal_code': '53204-1211',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'status': 'Terminated'},
#  {'country': 'United States',
#   'city': 'New York',
#   'address_1': '20 W 22nd St',
#   'reason_for_recall': 'Materne North America Corp. is voluntarily recalling specific packages of GoGo squeeZ¿ applesauce pouches due to potential adulteration from food product residue.',
#   'address_2': 'Ste 1604',
#   'product_quantity': '4,780,784 cases',
#   'code_info': 'GoGo squeeZ, non-organic Apple Sauce pouches, 3.2 oz., 12x4, 6 x 12, Apple/Mango Flavor Variety, Best Before Date of 12/4/15-3/4/17, Item No:s 120460; 120466; 120535.    Pouches have 5 digit Production Codes beginning with "US", and followed by  01, 02, 03, 04, 05, 06, 07 or 08; Cases have a 6-digit code ending in the last two digits 01, 02, 03, 04, 05, 06, 07 or 08.',
#   'center_classification_date': '20160420',
#   'distribution_pattern': 'Domestic: Nationwide- AL; AR; AZ; CA; CO;CT; DE; FL; GA; HI; IA; ID; IL; IN; KS; KY; LA; MA; MD; ME; MI; MN; MO; MS; NC; ND; NE; NH; NJ; NM; NV; NY; OH; OK; OR; PA; SC; SD;TN; TX; UT; VA; VT; WA; WI    No VA/DOD    Foreign: Canada, France',
#   'state': 'NY',
#   'product_description': 'GoGo squeeZ, non-organic Apple Sauce pouches, 3.2 oz., 12x4, 6 x 12, Apple/Mango Flavor Variety',
#   'report_date': '20160427',
#   'classification': 'Class II',
#   'openfda': {},
#   'recalling_firm': 'Materne North America Corp',
#   'recall_number': 'F-1111-2016',
#   'initial_firm_notification': 'Press Release',
#   'product_type': 'Food',
#   'event_id': '73471',
#   'termination_date': '20170323',
#   'recall_initiation_date': '20160304',
#   'postal_code': '10010-5875',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'status': 'Terminated'},
#  {'country': 'United States',
#   'city': 'Twin Falls',
#   'address_1': '3450 Kimberly Rd',
#   'reason_for_recall': 'Greek yogurt product Chobani brand is recalled due to report of illnesses and product bloated and swollen.',
#   'address_2': '',
#   'product_quantity': '121,992 cases',
#   'code_info': 'Sep 11-13 (four didit time stamp) to Oct 07-13 (four digit time stamp) 16-012.  This code is interpreted as Best By dates September 11, 2013 through October 07, 2013; 16-012 is the IMS number of a production plant in Twin Falls, Idaho.',
#   'center_classification_date': '20131021',
#   'distribution_pattern': 'distributed nationwide',
#   'state': 'ID',
#   'product_description': 'The Chobani Flip product come in 5.3oz (150g) square plastic containers with a foil lid.  There are 12 containers per pack.    Chobani 1.5% Milkfat Low-Fat Greek Yogurt Almond Coco Loco-Flip, UPC 8-18290-01228-9',
#   'report_date': '20131030',
#   'classification': 'Class II',
#   'openfda': {},
#   'recalling_firm': 'Chobani Idaho',
#   'recall_number': 'F-0073-2014',
#   'initial_firm_notification': 'Press Release',
#   'product_type': 'Food',
#   'event_id': '66175',
#   'termination_date': '20151113',
#   'recall_initiation_date': '20130905',
#   'postal_code': '83301',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'status': 'Terminated'},
#  {'country': 'United States',
#   'city': 'New Baltimore',
#   'address_1': '51005 Washington St',
#   'reason_for_recall': 'The finished product labels do not declare sub-ingredients of Wheat (flour).',
#   'address_2': '',
#   'product_quantity': '60 (2 count) packages',
#   'code_info': 'Fresh thru WED 5-2',
#   'center_classification_date': '20120612',
#   'distribution_pattern': 'Michigan Distribution Only',
#   'state': 'MI',
#   'product_description': "Cinnamon Rolls A Pastry Ingredients: Spring Flour (unbleached), water, powdered sugar sugar, vegetable shortening Net Wt 8oz Stahl's Bakery (586) 716-8500",
#   'report_date': '20120620',
#   'classification': 'Class II',
#   'openfda': {},
#   'recalling_firm': 'JDS Bakery LLC',
#   'recall_number': 'F-1404-2012',
#   'initial_firm_notification': 'Visit',
#   'product_type': 'Food',
#   'event_id': '61976',
#   'termination_date': '20130827',
#   'more_code_info': '',
#   'recall_initiation_date': '20120426',
#   'postal_code': '48047-2158',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'status': 'Terminated'},
#  {'country': 'United States',
#   'city': 'Windermere',
#   'address_1': '4757 The Grove Dr',
#   'reason_for_recall': 'Ready to Eat salad products containing iceberg lettuce, red cabbage and/or carrot ingredients are recalled due to a possible health risk from Cyclospora.',
#   'address_2': '',
#   'product_quantity': 'unknown',
#   'code_info': 'Product Code  Z158, Z162, Z163, Z164. USED BY or Before 7/08/2020',
#   'center_classification_date': '20200804',
#   'distribution_pattern': 'Domestic: Midwestern states of AR, CT, DC, DE, IA, IL, IN, KS, KY, MA, MD, ME, MI, MN, MO, MT, NC, ND, NE, NH, NJ, NY, OH, OK, PA, RI, SD, TN, VA, VT, WI, WV  Foreign: Canada',
#   'state': 'FL',
#   'product_description': 'Hy-Vee Chopped Kit Chipotle Cheddar Salad 11.4 oz., UPC 075450246728, Green & red cabbage & green onions',
#   'report_date': '20200722',
#   'classification': 'Class II',
#   'openfda': {},
#   'recalling_firm': 'Fresh Express Incorporated',
#   'recall_number': 'F-1101-2020',
#   'initial_firm_notification': 'E-Mail',
#   'product_type': 'Food',
#   'event_id': '85918',
#   'termination_date': '20201216',
#   'recall_initiation_date': '20200619',
#   'postal_code': '34786-8426',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'status': 'Terminated'},
#  {'country': 'United States',
#   'city': 'Port Townsend',
#   'address_1': '631 Water St',
#   'reason_for_recall': 'Elevated brand ice cream products are being recalled due to the potential to be contaminated with Listeria monocytogenes.  These products contain ice cream mix produced and recalled by Snoqualmie Gourmet Ice Cream',
#   'address_2': '',
#   'product_quantity': '10 batches',
#   'code_info': 'Some containers may have a production date hand written on a white label. Some quart containers are stamped on the bottom with the julian date.',
#   'center_classification_date': '20150220',
#   'distribution_pattern': 'All product was distributed in the local Port Townsend, Washington area.',
#   'state': 'WA',
#   'product_description': 'Ginger Snap Ice Cream  Product can be packaged in 2.5 gallon or 1.5 gallon plastic tubs or cardboard quart container.  Firm is unable to determine how batches were packaged.',
#   'report_date': '20150304',
#   'classification': 'Class I',
#   'openfda': {},
#   'recalling_firm': 'Elevated Ice Cream Company',
#   'recall_number': 'F-1252-2015',
#   'initial_firm_notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#   'product_type': 'Food',
#   'event_id': '70354',
#   'termination_date': '20150223',
#   'more_code_info': '',
#   'recall_initiation_date': '20141223',
#   'postal_code': '98368-5726',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'status': 'Terminated'},
#  {'country': 'United States',
#   'city': 'College Park',
#   'address_1': '2225 Riverdale Rd',
#   'reason_for_recall': 'The firm determined that the food was not held at an appropriate temperature. Because of the time-temperature relationship of the environment this food could be unsafe to consume.',
#   'address_2': '',
#   'product_quantity': '17cs/8/7.8oz bags',
#   'code_info': 'All lot codes shipped between 7/14/2021 and 8/13/2021',
#   'center_classification_date': '20210920',
#   'distribution_pattern': 'Product was shipped to the following states: GA, NC & TN.',
#   'state': 'GA',
#   'product_description': 'DAIYA CHEESE VEGAN CHEDDAR STYLE SLICE 8/7.8oz Plastic bag MANUFACDTURED BY: DAIYA FOODS INC., BURNABY, BC CANADA VSA 4R4 PRODUCT OF CANADA KEEP REFRIGERATED UPC 3 08 71459 00022 1',
#   'report_date': '20210929',
#   'classification': 'Class II',
#   'openfda': {},
#   'recalling_firm': 'Sysco Atlanta, LLC',
#   'recall_number': 'F-0992-2021',
#   'initial_firm_notification': 'Letter',
#   'product_type': 'Food',
#   'event_id': '88509',
#   'more_code_info': '',
#   'recall_initiation_date': '20210813',
#   'postal_code': '30337-5111',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'status': 'Completed'}]

# %%
# prduce df for data storage
df = pd.DataFrame(columns=["Country","City","Recall Reason","Quantity","Product Description","Class","Firm","Type","Status"])

# %%
# function to obtain fda details 

def get_fda_details(df):

    for vid in response['results']:
        country = vid['country']
        city = vid['city']
        recall_reason = vid['reason_for_recall']
        quantity = vid['product_quantity']
        product_desc = vid['product_description']
        classi = vid['classification']
        firm = vid['recalling_firm']
        types = vid['product_type']
        status = vid['status']
        
        df = df.append({"Country":country,"City":city,"Recall Reason":recall_reason,"Quantity":quantity,
                        "Product Description": product_desc,"Class":classi,"Firm":firm,"Type":types,"Status":status}, ignore_index=True
        )

    return df

# %%
df = get_fda_details(df)

# %%
df
# Out:
#            Country              City  \
# 0    United States             Davie
# 1    United States          Millbrae
# 2    United States             Miami
# 3    United States     Pompano Beach
# 4    United States  Rancho Dominguez
# ..             ...               ...
# 995  United States        Twin Falls
# 996  United States     New Baltimore
# 997  United States        Windermere
# 998  United States     Port Townsend
# 999  United States      College Park
#
#                                          Recall Reason  \
# 0    Recall initiated as a precautionary measure du...
# 1    Mooncake products, manufactured and distribute...
# 2    Virginia State (VDACS) found Listeria monocyto...
# 3    FreshPoint South Florida is recalling sliced f...
# 4    Firm was notified by supplier that Organic Gro...
# ..                                                 ...
# 995  Greek yogurt product Chobani brand is recalled...
# 996  The finished product labels do not declare sub...
# 997  Ready to Eat salad products containing iceberg...
# 998  Elevated brand ice cream products are being re...
# 999  The firm determined that the food was not held...
#
#                        Quantity  \
# 0                 1,990 bottles
# 1    2 cases (1 pc/bx, 48bx/cs)
# 2                    144 pieces
# 3                       7 cases
# 4                            xx
# ..                          ...
# 995               121,992 cases
# 996       60 (2 count) packages
# 997                     unknown
# 998                  10 batches
# 999           17cs/8/7.8oz bags
#
#                                    Product Description      Class  \
# 0    CytoDetox, Hydrolyzed Clinoptilolite Fragments...   Class II
# 1    Koi Palace Mini Moon Cake: Single Box - Mini O...   Class II
# 2    Crema GuateLinda (Guatemalan Style Cream) in i...    Class I
# 3    Yellow Onion.  Product is labeled in part:  "*...    Class I
# 4    Pure Planet Organic Parasite Cleanse;  Net Wt....  Class III
# ..                                                 ...        ...
# 995  The Chobani Flip product come in 5.3oz (150g) ...   Class II
# 996  Cinnamon Rolls A Pastry Ingredients: Spring Fl...   Class II
# 997  Hy-Vee Chopped Kit Chipotle Cheddar Salad 11.4...   Class II
# 998  Ginger Snap Ice Cream  Product can be packaged...    Class I
# 999  DAIYA CHEESE VEGAN CHEDDAR STYLE SLICE 8/7.8oz...   Class II
#
#                            Firm  Type      Status
# 0                Pharmatech LLC  Food     Ongoing
# 1     Magic Gourmet Trading Inc  Food  Terminated
# 2             Oasis Brands, Inc  Food  Terminated
# 3      FreshPoint South Florida  Food  Terminated
# 4       Organic By Nature, Inc.  Food  Terminated
# ..                          ...   ...         ...
# 995               Chobani Idaho  Food  Terminated
# 996              JDS Bakery LLC  Food  Terminated
# 997  Fresh Express Incorporated  Food  Terminated
# 998  Elevated Ice Cream Company  Food  Terminated
# 999          Sysco Atlanta, LLC  Food   Completed
#
# [1000 rows x 9 columns]
